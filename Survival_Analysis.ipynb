# %% [markdown]
# # Survival Analysis

# %% [markdown]
# ### Contents
# * [Parametric models](#Parametric-models)
# * [CLV](#CLV)
# * [Report](#Report)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from lifelines import WeibullAFTFitter, LogNormalAFTFitter, LogLogisticAFTFitter, ExponentialFitter, GeneralizedGammaFitter
from sklearn.model_selection import train_test_split

# %%
# Loading the data
telco = pd.read_csv('telco.csv')
telco.drop('ID', axis=1, inplace=True)

# %%
telco.head(3)
# Out:
#    region  tenure  age  marital  address  income  \
# 0  Zone 2      13   44  Married        9      64
# 1  Zone 3      11   33  Married        7     136
# 2  Zone 3      68   52  Married       24     116
#
#                              ed retire  gender voice internet forward  \
# 0                College degree     No    Male    No       No     Yes
# 1     Post-undergraduate degree     No    Male   Yes       No     Yes
# 2  Did not complete high school     No  Female    No       No      No
#
#          custcat churn
# 0  Basic service   Yes
# 1  Total service   Yes
# 2   Plus service    No

# %%
# Converting categorical variables to dummy variables
cat_cols = ['region', 'marital', 'ed', 'retire', 'gender', 'voice', 'internet', 'forward', 'custcat', 'churn']
df = telco.copy()
df = pd.get_dummies(df, columns=cat_cols, drop_first=True)
df = df.rename(columns={'churn_Yes': 'churn'})

# %%
df.head(3)
# Out:
#    tenure  age  address  income  region_Zone 2  region_Zone 3  \
# 0      13   44        9      64           True          False
# 1      11   33        7     136          False           True
# 2      68   52       24     116          False           True
#
#    marital_Unmarried  ed_Did not complete high school  ed_High school degree  \
# 0              False                            False                  False
# 1              False                            False                  False
# 2              False                             True                  False
#
#    ed_Post-undergraduate degree  ed_Some college  retire_Yes  gender_Male  \
# 0                         False            False       False         True
# 1                          True            False       False         True
# 2                         False            False       False        False
#
#    voice_Yes  internet_Yes  forward_Yes  custcat_E-service  \
# ...

# %% [markdown]
# # Parametric models <a class="anchor" id="Parametric-models"></a>

# %% [markdown]
# ### Building the parametric models

# %%
# Fitting the Weibull AFT model
weibull_aft = WeibullAFTFitter()
weibull_aft.fit(df, duration_col='tenure', event_col='churn')

# Fitting the Log-Normal AFT model
lognormal_aft = LogNormalAFTFitter()
lognormal_aft.fit(df, duration_col='tenure', event_col='churn')

# Fitting the Log-Logistic AFT model
loglogistic_aft = LogLogisticAFTFitter()
loglogistic_aft.fit(df, duration_col='tenure', event_col='churn')

# Fitting the Exponential AFT model
exponential_aft = ExponentialFitter()
exponential_aft.fit(df['tenure'], df['churn'])

# Fitting the Generalized Gamma AFT model
generalizedgamma_aft = GeneralizedGammaFitter()
generalizedgamma_aft.fit(df['tenure'], df['churn'])
# Out:
# <lifelines.GeneralizedGammaFitter:"GeneralizedGamma_estimate", fitted with 1000 total observations, 726 right-censored observations>

# %% [markdown]
# ### Comparing the models

# %%
# Printing summary statistics for each model
print("Weibull AFT model:")
print(weibull_aft.print_summary())
print("\nLog-Normal AFT model:")
print(lognormal_aft.print_summary())
print("\nLog-Logistic AFT model:")
print(loglogistic_aft.print_summary())
print("\nExponential AFT model:")
print(exponential_aft.print_summary())
print("\nGeneralized Gamma AFT model:")
print(generalizedgamma_aft.print_summary())
# Out:
# Weibull AFT model:
# <lifelines.WeibullAFTFitter: fitted with 1000 total observations, 726 right-censored observations>
#              duration col = 'tenure'
#                 event col = 'churn'
#    number of observations = 1000
# number of events observed = 274
#            log-likelihood = -1462.17
#          time fit was run = 2024-05-01 15:37:27 UTC
#
# ---
#                                           coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# param   covariate
# lambda_ address                           0.04       1.04       0.01             0.02             0.06                 1.02                 1.06
#         age                               0.03       1.03       0.01             0.01             0.04                 1.01                 1.04
#         custcat_E-service                 0.98       2.66       0.16             0.67             1.28                 1.96                 3.61
# ...

# %%
print('Median Survival Time')
print(f'Weibull: {weibull_aft.median_survival_time_}')
print(f'Log-Normal: {lognormal_aft.median_survival_time_}')
print(f'Log-Logistic: {loglogistic_aft.median_survival_time_}')
print(f'Exponential: {exponential_aft.median_survival_time_}')
print(f'Generalized Gamma: {generalizedgamma_aft.median_survival_time_}')
# Out:
# Median Survival Time
# Weibull: 38.84764928679467
# Log-Normal: 38.953910678318685
# Log-Logistic: 36.11065472580489
# Exponential: 89.87133805042757
# Generalized Gamma: 113.9237895860889

# %% [markdown]
# **To compare the models, we can calculate the AIC values for each model and select the one with the lowest AIC value.**

# %%
models_aic={}
weibull_aic = weibull_aft.AIC_
print(f'{weibull_aic = }')
models_aic['Weibull']=weibull_aic
lognormal_aic = lognormal_aft.AIC_
print(f'{lognormal_aic = }')
models_aic['Log-Normal']=lognormal_aic
loglogistic_aic = loglogistic_aft.AIC_
print(f'{loglogistic_aic = }')
models_aic['Log-Logistic']=loglogistic_aic
exponential_aic = exponential_aft.AIC_
print(f'{exponential_aic = }')
models_aic['Exponential']=exponential_aic
generalizedgamma_aic = generalizedgamma_aft.AIC_
print(f'{generalizedgamma_aic = }')
models_aic['Generalized Gamma']=generalizedgamma_aic
# Out:
# weibull_aic = 2964.343248083881
# lognormal_aic = 2954.0240102517123
# loglogistic_aic = 2956.2085614433336
# exponential_aic = 3215.9608134637247
# generalizedgamma_aic = 3211.0611993446437

# %%
min_aic_model = min(models_aic, key=models_aic.get)
min_aic_value = models_aic[min_aic_model]
print(f"The model with the minimum AIC value is {min_aic_model} with AIC = {min_aic_value}")
# Out:
# The model with the minimum AIC value is Log-Normal with AIC = 2954.0240102517123

# %% [markdown]
# ### Visualizing all the curves

# %%
# Predicting survival function for each model
weibull_sf = weibull_aft.predict_survival_function(df)
lognormal_sf = lognormal_aft.predict_survival_function(df)
loglogistic_sf = loglogistic_aft.predict_survival_function(df)
exponential_sf = exponential_aft.survival_function_
generalizedgamma_sf = generalizedgamma_aft.survival_function_

# Plotting the survival function
plt.figure(figsize=(10, 6))
plt.plot(weibull_sf.index, weibull_sf.mean(1), label='Weibull')
plt.plot(lognormal_sf.index, lognormal_sf.mean(1), label='Log-Normal')
plt.plot(loglogistic_sf.index, loglogistic_sf.mean(1), label='Log-Logistic')
plt.plot(exponential_sf.index, exponential_sf.mean(1), label='Exponential')
plt.plot(generalizedgamma_sf.index, generalizedgamma_sf.mean(1), label='Generalized Gamma')

plt.xlabel('Tenure (months)')
plt.ylabel('Survival Probability')
plt.title('Survival Curves')
plt.legend()
plt.show()

# %% [markdown]
# ### Choosing the final model

# %%
# selecting the best model
models = [weibull_aft, lognormal_aft, loglogistic_aft, exponential_aft, generalizedgamma_aft]
best_model = models[np.argmin([m.AIC_ for m in models])]
print('Best model:', type(best_model).__name__)
# Out:
# Best model: LogNormalAFTFitter

# %%
print(best_model.print_summary())
# Out:
# <lifelines.LogNormalAFTFitter: fitted with 1000 total observations, 726 right-censored observations>
#              duration col = 'tenure'
#                 event col = 'churn'
#    number of observations = 1000
# number of events observed = 274
#            log-likelihood = -1457.01
#          time fit was run = 2024-05-01 15:37:27 UTC
#
# ---
#                                          coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# param  covariate
# mu_    address                           0.04       1.04       0.01             0.03             0.06                 1.03                 1.06
#        age                               0.03       1.03       0.01             0.02             0.05                 1.02                 1.05
#        custcat_E-service                 1.07       2.90       0.17             0.73             1.40                 2.08                 4.06
# ...

# %% [markdown]
# ### Keeping siginficant features (considering the threshold for p value = 0.15)

# %%
# Getting the p-values of the features
p_values = best_model.summary['p']

# Selecting the statistically significant features (p-value < 0.15)
sig_cols = p_values[p_values < 0.15]

# Gettingthe significant column names
sign_cols = []
for tuple_ in sig_cols.keys().tolist():
    sign_cols.append(str(tuple_).split("'")[-2])
sign_cols = sign_cols[:-2]
sign_cols.append('tenure')
sign_cols.append('churn')

# subsetting the data to include only the significant columns and the target variable
df = df.loc[:, sign_cols]
df.head(3)
# Out:
#    address  age  custcat_E-service  custcat_Plus service  \
# 0        9   44              False                 False
# 1        7   33              False                 False
# 2       24   52              False                  True
#
#    custcat_Total service  ed_Did not complete high school  \
# 0                  False                            False
# 1                   True                            False
# 2                  False                             True
#
#    ed_High school degree  ed_Some college  income  internet_Yes  \
# 0                  False            False      64         False
# 1                  False            False     136         False
# 2                  False            False     116         False
#
#    marital_Unmarried  voice_Yes  tenure  churn
# 0              False      False      13   True
# 1              False       True      11   True
# 2              False      False      68  False

# %%
# Keeping the final model
lognormal = LogNormalAFTFitter()
lognormal.fit(df, duration_col='tenure', event_col='churn')
# Out:
# <lifelines.LogNormalAFTFitter: fitted with 1000 total observations, 726 right-censored observations>

# %% [markdown]
# # CLV <a class="anchor" id="CLV"></a>

# %% [markdown]
# ### CLV per customer

# %%
average_margin = 0.2
discount_rate = 0.1
retention_rate = 0.8

telco['CLV'] = (average_margin * (1 - discount_rate) * retention_rate) / (1 + discount_rate - retention_rate) * df['tenure']

telco.head(3)
# Out:
#    region  tenure  age  marital  address  income  \
# 0  Zone 2      13   44  Married        9      64
# 1  Zone 3      11   33  Married        7     136
# 2  Zone 3      68   52  Married       24     116
#
#                              ed retire  gender voice internet forward  \
# 0                College degree     No    Male    No       No     Yes
# 1     Post-undergraduate degree     No    Male   Yes       No     Yes
# 2  Did not complete high school     No  Female    No       No      No
#
#          custcat churn    CLV
# 0  Basic service   Yes   6.24
# 1  Total service   Yes   5.28
# 2   Plus service    No  32.64

# %% [markdown]
# ### CLV within different segments

# %%
columns = ['region', 'marital', 'ed', 'retire', 'gender', 'voice', 'internet', 'forward', 'custcat', 'churn']

for column in columns:
    sns.displot(telco, kind='kde', x='CLV', hue=column)
    plt.title(column)

# %%
for column in columns:
    print(telco.groupby(column)[["CLV"]].mean(), "\n")
# Out:
#               CLV
# region
# Zone 1  16.868571
# Zone 2  16.996886
# Zone 3  17.278605
#
#                  CLV
# marital
# Married    18.648242
# Unmarried  15.488317
#
#                                     CLV
# ed
# College degree                15.394872
# Did not complete high school  18.875294
# High school degree            17.726551
# Post-undergraduate degree     16.676364
# Some college                  16.322297
#
#               CLV
# retire
# No      16.663001
# Yes     24.949787
#
#               CLV
# gender
# Female  17.285571
# Male    16.802981
#
#              CLV
# voice
# No     17.090345
# Yes    16.965789
#
#                 CLV
# internet
# No        18.154177
# Yes       15.160435
#
#                CLV
# forward
# No       16.184615
# Yes      17.944990
#
#                      CLV
# custcat
# Basic service  11.844812
# E-service      20.805899
# Plus service   19.237580
# Total service  16.869153
#
#              CLV
# churn
# No     19.424793
# ...

# %% [markdown]
# <h1>Report</h1> <a class="anchor" id="Report"></a> The aim is to understand the variables influencing the likelihood of customer churn. <h3>Interpreting the coefficients</h3>To interpret the coefficients effectively, we can assess the Customer Lifetime Value (CLV) across different segments and make comparisons. For instance, we observe that retired customers exhibit a higher CLV compared to non-retired ones, while customers with a college degree tend to have a lower CLV than those with only a high school education or no high school diploma. <h3>Identifying Valuable Segments (Defining Value)</h3> In identifying the most valuable segments, we prioritize those with the highest CLV. These segments include customers subscribed to Plus or Total services, those who have not churned, and those not utilizing forwarding or internet services. However, it's important to note that the definition of being valuable can vary based on business objectives. For instance, a business might prioritize factors like customer satisfaction or revenue growth over CLV, thus altering which segments are deemed most valuable. <h3>Estimating Annual Retention Budget</h3> To estimate the annual retention budget, we need to first identify how many customers are at risk of churning within a year. We can do this by analyzing the customer data and estimating the probability of churn over time using survival analysis techniques. Once we know how many customers are at risk of churning, we can estimate the cost of retaining them using various strategies, such as offering discounts or incentives, providing excellent customer service, or improving the quality of the product or service. The annual retention budget will depend on the cost of these retention efforts and the expected return on investment from retaining customers. In other words, we need to weigh the cost of retaining customers against the potential revenue that they would generate for the business in the future. To detect the approximate number of at-risk subscribers within a year, we can use the predict_percentile method of the LogNormalAFTFitter class from the lifelines library. The predict_percentile method predicts the time at which a certain percentile of the customers will churn. We can use this method to predict the time at which 50% of the customers will churn, and count the number of customers whose tenure is less than the predicted time. <h3>Other suggestions for retention</h3> There are various strategies that can be used to improve retention. For example, improving customer service, offering loyalty programs or rewards, simplifying the purchasing process, providing personalized offers or recommendations, and improving the overall customer experience. Moreover, conducting surveys or gathering feedback from customers can pinpoint specific areas for improvement, allowing more targeted retention initiatives.n a year:ers within a year:
